# %% [markdown]
# In this notebook, we train character-based LSTM models to generate Shakespearean-style sonnets.

# %%
import numpy as np

from DataProcessing import *
from RNNProcessing import *

import keras
from keras.callbacks import EarlyStopping, LambdaCallback, ModelCheckpoint
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Without punctuation and newlines
# Read in Shakespearean sonnets with all punctuation and newlines removed, thus minimizing the number of input classes.

# %%
# Load data
sonnets, syllableDic = loadShake_char(stripPunc=True)
X_code, y_code, char2code, code2char = text2seq(sonnets)
X, y = seq2cat(X_code, y_code, len(char2code))

# Construct model
model = build_model_LSTM(X.shape[1:], y.shape[1])
model.summary()
# Out:
# WARNING:tensorflow:From C:\Users\chris_ibt8rn4\Anaconda3\envs\cms155\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 128)               80896
# _________________________________________________________________
# dense_1 (Dense)              (None, 29)                3741
# =================================================================
# Total params: 84,637
# Trainable params: 84,637
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Define callback functions for use in training.

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=50)

def epoch_chars(epoch, _):
    # Generate a sequence of characters after each epoch
    print('--------------- Epoch %d Completed ---------------' % epoch)
    seed = X_code[np.random.choice(len(X_code))]
    T = 1
    seq_out = gen_chars(model, seed, code2char, n_chars=100, T=T, verbose=False)
    print(seq_out + '\n')

def epoch_lines(epoch, _):
    # Generate a sequence of lines after each epoch
    print('--------------- Epoch %d Completed ---------------' % epoch)
    seed = X_code[np.random.choice(len(X_code))]
    T = 1
    seq_out = gen_lines(model, seed, code2char, n_lines=2, T=T, verbose=False)
    print(seq_out + '\n')

chars_callback = LambdaCallback(on_epoch_end=epoch_chars)
lines_callback = LambdaCallback(on_epoch_end=epoch_lines)

# %% [markdown]
# Train model.

# %%
# Compile and fit model
model.compile(optimizer='adam', loss='categorical_crossentropy',
              metrics=['accuracy'])
model.fit(X, y, batch_size=64, epochs=20,
          validation_split=0.2, callbacks=[chars_callback],
          verbose=1)

# Save model
model.save('RNN_char-LSTM_no-punc.h5')
# Out:
# WARNING:tensorflow:From C:\Users\chris_ibt8rn4\Anaconda3\envs\cms155\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 67713 samples, validate on 16929 samples
# Epoch 1/20
# 67713/67713 [==============================] - 95s 1ms/step - loss: 2.4118 - acc: 0.3078 - val_loss: 2.1305 - val_acc: 0.3743
# --------------- Epoch 0 Completed ---------------
# hl wire for deaut o tloun t beorgangh spil prell tort she ios io hing ir of bing sor arougth be and
#
# Epoch 2/20
# 67713/67713 [==============================] - 89s 1ms/step - loss: 2.0225 - acc: 0.4012 - val_loss: 1.9599 - val_acc: 0.4156
# --------------- Epoch 1 Completed ---------------
# t the weattcowr canker coich aif the me weates not ikeds havess gurd indy brapk and and wey wall ans
#
# Epoch 3/20
# 67713/67713 [==============================] - 89s 1ms/step - loss: 1.8896 - acc: 0.4361 - val_loss: 1.9003 - val_acc: 0.4270
# --------------- Epoch 2 Completed ---------------
#  deith sumerst mided sum'ss shape abe eters sing my yie that hos tany ses yous mall cun to se blose
#
# Epoch 4/20
# 67713/67713 [==============================] - 89s 1ms/step - loss: 1.8053 - acc: 0.4603 - val_loss: 1.8234 - val_acc: 0.4472
# --------------- Epoch 3 Completed ---------------
# w memers noon mo i coo thee ling wistike your when who prain and buceed of is moun cherte in but of
#
# Epoch 5/20
# 67713/67713 [==============================] - 90s 1ms/step - loss: 1.7367 - acc: 0.4738 - val_loss: 1.7784 - val_acc: 0.4583
# --------------- Epoch 4 Completed ---------------
# beld rake thou gree ster's se forth ant sey hesrace that heme wothes but brees in so liveouped and b
#
# Epoch 6/20
# 67713/67713 [==============================] - 89s 1ms/step - loss: 1.6873 - acc: 0.4881 - val_loss: 1.7402 - val_acc: 0.4672
# --------------- Epoch 5 Completed ---------------
# my verp which as thy efprend not tay it barked hear tille hary olt then by that whine eve shall kyon
#
# Epoch 7/20
# 67713/67713 [==============================] - 89s 1ms/step - loss: 1.6377 - acc: 0.4991 - val_loss: 1.7167 - val_acc: 0.4716
# --------------- Epoch 6 Completed ---------------
# eing then byon wind as preabrelss and corones befut from thou frammerks of should wrom a though con
#
# Epoch 8/20
# 67713/67713 [==============================] - 91s 1ms/step - loss: 1.5968 - acc: 0.5087 - val_loss: 1.6948 - val_acc: 0.4775
# --------------- Epoch 7 Completed ---------------
# o be dond inter pravose wond trow lest is wight of new burnstame if sulling mank and to than yit plo
#
# Epoch 9/20
# 67713/67713 [==============================] - 91s 1ms/step - loss: 1.5636 - acc: 0.5180 - val_loss: 1.6797 - val_acc: 0.4843
# --------------- Epoch 8 Completed ---------------
# king adililan's dore shame grown vile the weil tha were as and treasure graves in allfthand of my me
#
# Epoch 10/20
# 67713/67713 [==============================] - 91s 1ms/step - loss: 1.5328 - acc: 0.5267 - val_loss: 1.6773 - val_acc: 0.4859
# --------------- Epoch 9 Completed ---------------
# beauty parks angrefhars amony pear foultherst bleared invery thus wailest that to may be a heperpent
#
# Epoch 11/20
# 67713/67713 [==============================] - 91s 1ms/step - loss: 1.5030 - acc: 0.5360 - val_loss: 1.6561 - val_acc: 0.4918
# --------------- Epoch 10 Completed ---------------
# be drat never cas is he string my shill lose hisure ouldot of this strongs and scate time i chink on
#
# Epoch 12/20
# 67713/67713 [==============================] - 91s 1ms/step - loss: 1.4775 - acc: 0.5424 - val_loss: 1.6581 - val_acc: 0.4917
# --------------- Epoch 11 Completed ---------------
# rent-assured of you with owrands decays or newer where their so quide or part right sty not frame ho
#
# Epoch 13/20
# 67713/67713 [==============================] - 91s 1ms/step - loss: 1.4493 - acc: 0.5502 - val_loss: 1.6528 - val_acc: 0.4896
# --------------- Epoch 12 Completed ---------------
# wfece dained bur is rack for their my beauty grest of must leave to summer we done one cheary and ta
#
# Epoch 14/20
# 67713/67713 [==============================] - 98s 1ms/step - loss: 1.4252 - acc: 0.5564 - val_loss: 1.6572 - val_acc: 0.4873
# --------------- Epoch 13 Completed ---------------
# reon lide a weralle quipless anp in thy present eoch the lict i for shame on hend and my lilaw excus
#
# Epoch 15/20
# 67713/67713 [==============================] - 101s 1ms/step - loss: 1.4025 - acc: 0.5616 - val_loss: 1.6612 - val_acc: 0.4889
# --------------- Epoch 14 Completed ---------------
# t fainamend thy smery being sine own his warking but excrount of youth with glory yet and foom her m
#
# Epoch 16/20
# 67713/67713 [==============================] - 101s 1ms/step - loss: 1.3799 - acc: 0.5690 - val_loss: 1.6677 - val_acc: 0.4861
# --------------- Epoch 15 Completed ---------------
# on te posiry dubleds sweet sweet but beaupy and you frimids greet her my love and sickles moon's eig
#
# Epoch 17/20
# 67713/67713 [==============================] - 100s 1ms/step - loss: 1.3568 - acc: 0.5747 - val_loss: 1.6664 - val_acc: 0.4886
# --------------- Epoch 16 Completed ---------------
#  farge sto bepore how i juck such more on neter's rriost i tempain agave creatmed being thiel string
#
# Epoch 18/20
# 67713/67713 [==============================] - 100s 1ms/step - loss: 1.3337 - acc: 0.5813 - val_loss: 1.6799 - val_acc: 0.4860
# --------------- Epoch 17 Completed ---------------
#  thou self deigust bressest kild confork sour with his time appesser-bureess shall deaw begrives tha
#
# Epoch 19/20
# 67713/67713 [==============================] - 101s 1ms/step - loss: 1.3124 - acc: 0.5884 - val_loss: 1.6866 - val_acc: 0.4860
# --------------- Epoch 18 Completed ---------------
# e no so must for me beauth ints by timmer beting of age in reage dights on these thinks breast so to
#
# Epoch 20/20
# 67713/67713 [==============================] - 101s 1ms/step - loss: 1.2926 - acc: 0.5930 - val_loss: 1.7054 - val_acc: 0.4786
# --------------- Epoch 19 Completed ---------------
# outh of the being and make this save so my mide eves outand singressote eace base hawn then fen ince

# %% [markdown]
# Generate example text from trained model.

# %%
# Load model
model = keras.models.load_model('RNN_char-LSTM_no-punc.h5')

# Choose seed
seed = X_code[np.random.choice(len(X_code))]
print('Seed Sequence:')
print(''.join([code2char[code] for code in seed]))
print('')

# Generate sequences for different temperatures
for T in [0.5, 1, 1.5]:
    seq_out = gen_chars(model, seed, code2char, n_chars=1000, T=T,
                        verbose=False)
    print('Output Sequence for Temperature %.1f:' % T)
    print(seq_out)
    print('')
# Out:
# Seed Sequence:
#  thy will and will to boot and will in o
#
# Output Sequence for Temperature 0.5:
# f thy self and thy past and thou be doth days and beauty's since the seem the wanter that my wide what i sum condect of hould in these can see since a change mine on thy self i joy thy hears breathe to be then to be then that they mayst like and the same and the serves the fince that is thy self the self do blessing mine own my grace which show thine own seeming the beauty's will i thine eye as the living beauty's painted what waster which lead the love that this thoughts on thee my love you be despite of shame were but the lease that thou decay so thou the still with the bear my love that thou art bearseness every with when i am and all your sall the time's thee their hadding thine of thee thy good than hampering thy self to break i for their brink nothing of the with they dead that though they then the world and the basest and this will to steal hear the world or all were borness and like and look is beauty and by the stranges of plais not such a night and the thing that i speet by t
#
# Output Sequence for Temperature 1.0:
# ld ithing fountance if thy labe sweet assunds bus that words others bo try slore thee are words and then lerves of fors and all externed so nay is the warker of this is edusb and every on there blest to redon pacgil doth beauty's and my self a wollart porthor and lace no conssing stey she salved to be bow thing hew like and were be mode thine own assed gonely deppiternancay as truth as ance and me this how a do you virths deighs impleased are of thy fucwering clouds confenterispit for love beauty's conquention be thy ashange agains thy rand night him uble vrie what hath the anquaintened from his sight i will or should be in thy deatest need hin curmanty so to pleasprefegoss hin love not thy dear quilate gives thee thy self it give beaute's bried to as thou mbrugd bess faired dissedce's frixhe shalows when yet an ontes my gresss exemment their briv's thine so you do she this days art if incees i vilbered white goupless interdidized that bress till i worn where oll lown to soll soul swee
#
# Output Sequence for Temperature 1.5:
#  relon laic wuld soth now newmy giviling ho sein agchey ont despienched dightson in iblinuphess please ansuehest painder pectil ceremitiig thou although rekiment comwhsont o am phacked cun juch but bidds of your migd's gazeth edure is book book agaiced and though payst likein aloness knowpnownstsless with your beauteire tatte hom meitonouts be aly trues mrremagil hurg apsist the worncg faula time in my vears's cieds repwifures roverlieg with a dosencace shep repait from held's hense amssy captless as refoeb age drefelifer faute of formunt wight ty-moy' nod espessigiry my heir do injerestall thy year leid not winfensedver shortese wails woll kied huply raiding mich pay fordion cwilpiiganiom trumow dost wigh that thougn disbull provy tlanes invryeacatile somp watre diest wold ald thinving goidebpciughtsos yourldssmy zediwly nigzards silznutuextors time minutes pastsly anged hurherbs fiesm'nous hever regiits o'hfly befeemel ofled lited in these coubse bleng aghiny ain upin miny nog up ere

# %% [markdown]
# ## With punctuation and newlines
# Read in Shakespearean sonnets with all punctuation and newlines preserved, enabling learning of the natural poem structure.

# %%
# Load data
sonnets, syllableDic = loadShake_char(stripPunc=False)
X_code, y_code, char2code, code2char = text2seq(sonnets)
X, y = seq2cat(X_code, y_code, len(char2code))

# Construct model
model = build_model_LSTM(X.shape[1:], y.shape[1])
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_2 (LSTM)                (None, 128)               85504
# _________________________________________________________________
# dense_2 (Dense)              (None, 38)                4902
# =================================================================
# Total params: 90,406
# Trainable params: 90,406
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Train model, this time for up to 200 epochs.

# %%
# Add model checkpoint
model_checkpoint = ModelCheckpoint('RNN_char-LSTM.h5',
                                   monitor='val_loss', save_best_only=True)

# Compile and fit model
model.compile(optimizer='adam', loss='categorical_crossentropy',
              metrics=['accuracy'])
fit = model.fit(X, y, batch_size=64, epochs=200,
                validation_split=0.2,
                callbacks=[early_stopping, model_checkpoint, lines_callback],
                verbose=1)
# Out:
# Train on 70503 samples, validate on 17626 samples
# Epoch 1/200
# 70503/70503 [==============================] - 95s 1ms/step - loss: 2.5529 - acc: 0.2752 - val_loss: 2.2326 - val_acc: 0.3505
# --------------- Epoch 0 Completed ---------------
# sst arko iy inatt be qirltuncs ord wdtexk fes rand sith clan thith llleish dons raske dos id theugl co demes en pepllsd,
# n wh mo mowemenfegron seofg it lo thakr
#
# Epoch 2/200
# 70503/70503 [==============================] - 93s 1ms/step - loss: 2.1310 - acc: 0.3762 - val_loss: 2.0573 - val_acc: 0.3923
# --------------- Epoch 1 Completed ---------------
# odangs,
# ind divej, on the prate
#
# Epoch 3/200
# 70503/70503 [==============================] - 95s 1ms/step - loss: 1.9756 - acc: 0.4164 - val_loss: 1.9503 - val_acc: 0.4205
# --------------- Epoch 2 Completed ---------------
#  thy lizh's sonn,
# ao suma, thet thou wastaye,
#
# Epoch 4/200
# 70503/70503 [==============================] - 96s 1ms/step - loss: 1.8634 - acc: 0.4462 - val_loss: 1.8712 - val_acc: 0.4359
# --------------- Epoch 3 Completed ---------------
#
# wher quives tifvest dall doin was framtires.
#
# Epoch 5/200
# 70503/70503 [==============================] - 101s 1ms/step - loss: 1.7913 - acc: 0.4638 - val_loss: 1.8251 - val_acc: 0.4500
# --------------- Epoch 4 Completed ---------------
# dealld?
# in love thiils one faixred in meropn,
#
# Epoch 6/200
# 70503/70503 [==============================] - 101s 1ms/step - loss: 1.7346 - acc: 0.4761 - val_loss: 1.7880 - val_acc: 0.4563
# --------------- Epoch 5 Completed ---------------
# s in my pors as poresst.
#   helx as peit lovend that dong erose my wall,
#
# Epoch 7/200
# 70503/70503 [==============================] - 101s 1ms/step - loss: 1.6891 - acc: 0.4887 - val_loss: 1.7640 - val_acc: 0.4639
# --------------- Epoch 6 Completed ---------------
# ving (reamalre
# what hy plaster shall of i wromper cale
#
# Epoch 8/200
# 70503/70503 [==============================] - 101s 1ms/step - loss: 1.6487 - acc: 0.4980 - val_loss: 1.7524 - val_acc: 0.4661
# --------------- Epoch 7 Completed ---------------
# will natine is manker,
# eme wirch cownben so fimelew the remome forped,
#
# Epoch 9/200
# 70503/70503 [==============================] - 101s 1ms/step - loss: 1.6139 - acc: 0.5066 - val_loss: 1.7289 - val_acc: 0.4727
# --------------- Epoch 8 Completed ---------------
# that plowge your fare wid,
# hom the more what kead aby angee by good,
#
# Epoch 10/200
# 70503/70503 [==============================] - 101s 1ms/step - loss: 1.5813 - acc: 0.5167 - val_loss: 1.7186 - val_acc: 0.4779
# --------------- Epoch 9 Completed ---------------
# e pravin as my heared nod goring sight,
# whoned i rach shore voue ginting see fure,
#
# Epoch 11/200
# 70503/70503 [==============================] - 101s 1ms/step - loss: 1.5522 - acc: 0.5248 - val_loss: 1.7084 - val_acc: 0.4826
# --------------- Epoch 10 Completed ---------------
#  hid as thinks do hind, in their dasted,
# thy gent hours, mast that plea in shall a topay,
#
# Epoch 12/200
# 70503/70503 [==============================] - 101s 1ms/step - loss: 1.5243 - acc: 0.5317 - val_loss: 1.7025 - val_acc: 0.4818
# --------------- Epoch 11 Completed ---------------
# the times didce,
# and your still are thys doth ip for not sweet,
#
# Epoch 13/200
# 70503/70503 [==============================] - 101s 1ms/step - loss: 1.4982 - acc: 0.5395 - val_loss: 1.7076 - val_acc: 0.4795
# --------------- Epoch 12 Completed ---------------
# my live oo wite,
# and in thie mine hishal to gonds of eyes,
#
# Epoch 14/200
# 70503/70503 [==============================] - 101s 1ms/step - loss: 1.4736 - acc: 0.5461 - val_loss: 1.7117 - val_acc: 0.4808
# --------------- Epoch 13 Completed ---------------
#  loven poocts or swart crang:
# thy wear i hand and, greit bads these beauty?
#
# Epoch 15/200
# 70503/70503 [==============================] - 101s 1ms/step - loss: 1.4500 - acc: 0.5516 - val_loss: 1.7048 - val_acc: 0.4839
# --------------- Epoch 14 Completed ---------------
#  our swauted,
# and their gloss caurs heart's hask of the sprainedsed,
#
# Epoch 16/200
# 70503/70503 [==============================] - 98s 1ms/step - loss: 1.4261 - acc: 0.5596 - val_loss: 1.7026 - val_acc: 0.4892
# --------------- Epoch 15 Completed ---------------
# inglose wor.
#   a'ligh enough burd but did appaaich whise
#
# Epoch 17/200
# 70503/70503 [==============================] - 101s 1ms/step - loss: 1.4039 - acc: 0.5664 - val_loss: 1.7137 - val_acc: 0.4863
# --------------- Epoch 16 Completed ---------------
# ime,
# but so my bried hid wretces trougly broudsh so.
#
# Epoch 18/200
# 70503/70503 [==============================] - 103s 1ms/step - loss: 1.3812 - acc: 0.5721 - val_loss: 1.7078 - val_acc: 0.4864
# --------------- Epoch 17 Completed ---------------
# war this growty.
#   and even of sucleving others manker vross,
#
# Epoch 19/200
# 70503/70503 [==============================] - 101s 1ms/step - loss: 1.3603 - acc: 0.5781 - val_loss: 1.7197 - val_acc: 0.4874
# --------------- Epoch 18 Completed ---------------
# ome,
# whilled which plays it or atique though's me,
#
# Epoch 20/200
# 70503/70503 [==============================] - 101s 1ms/step - loss: 1.3377 - acc: 0.5849 - val_loss: 1.7338 - val_acc: 0.4831
# --------------- Epoch 19 Completed ---------------
# h cleasure gatt ase so th? his wil'sting,
#   me all you dild's wintrue forgaud leaved,
#
# Epoch 21/200
# 70503/70503 [==============================] - 101s 1ms/step - loss: 1.3174 - acc: 0.5928 - val_loss: 1.7538 - val_acc: 0.4781
# --------------- Epoch 20 Completed ---------------
# athee you wolld with prive.
#   thou hew aucest mide and this, what seed,
#
# Epoch 22/200
# 70503/70503 [==============================] - 101s 1ms/step - loss: 1.2964 - acc: 0.5965 - val_loss: 1.7565 - val_acc: 0.4811
# --------------- Epoch 21 Completed ---------------
# f the with part inilest sigh
# fit am, i canstant, from seal hath lassed,
#
# Epoch 23/200
# 70503/70503 [==============================] - 99s 1ms/step - loss: 1.2757 - acc: 0.6043 - val_loss: 1.7574 - val_acc: 0.4826
# --------------- Epoch 22 Completed ---------------
# y,
# so storr what thou bystiff's exerrapiniggnd,
#
# Epoch 24/200
# 70503/70503 [==============================] - 101s 1ms/step - loss: 1.2570 - acc: 0.6082 - val_loss: 1.7746 - val_acc: 0.4785
# --------------- Epoch 23 Completed ---------------
# ath on mine own wrich worth to long,
# mimean pluck as counded doth news your liss alage,
#
# Epoch 25/200
# 70503/70503 [==============================] - 101s 1ms/step - loss: 1.2365 - acc: 0.6140 - val_loss: 1.7970 - val_acc: 0.4767
# --------------- Epoch 24 Completed ---------------
# cked ?
# courn's is tamsed te poub
#
# Epoch 26/200
# 70503/70503 [==============================] - 102s 1ms/step - loss: 1.2179 - acc: 0.6198 - val_loss: 1.8125 - val_acc: 0.4740
# --------------- Epoch 25 Completed ---------------
#  ommeried you writ, to let hors:
# in heaved to brand but be in my patale
#
# Epoch 27/200
# 70503/70503 [==============================] - 102s 1ms/step - loss: 1.1984 - acc: 0.6249 - val_loss: 1.8244 - val_acc: 0.4748
# --------------- Epoch 26 Completed ---------------
#  the remove never look,
# and reiment of many poof, thee have'
#
# Epoch 28/200
# 70503/70503 [==============================] - 102s 1ms/step - loss: 1.1788 - acc: 0.6315 - val_loss: 1.8437 - val_acc: 0.4715
# --------------- Epoch 27 Completed ---------------
# amust thy shider with my sing,
# and tone, (regking himfald time thee may.
#
# Epoch 29/200
# 70503/70503 [==============================] - 103s 1ms/step - loss: 1.1594 - acc: 0.6378 - val_loss: 1.8619 - val_acc: 0.4631
# --------------- Epoch 28 Completed ---------------
# ves shall ober
# whoch sunceered thine eyes tisel i antune,
#
# Epoch 30/200
# 70503/70503 [==============================] - 98s 1ms/step - loss: 1.1406 - acc: 0.6433 - val_loss: 1.8805 - val_acc: 0.4662
# --------------- Epoch 29 Completed ---------------
# n the dessesseake,
# and 'tiss this by duppace me withoul scond
#
# Epoch 31/200
# 70503/70503 [==============================] - 95s 1ms/step - loss: 1.1244 - acc: 0.6504 - val_loss: 1.8969 - val_acc: 0.4672
# --------------- Epoch 30 Completed ---------------
# f timer speaker eyes couchthing beauty's wist,
# so you licting that this admorn his game,
#
# Epoch 32/200
# 70503/70503 [==============================] - 102s 1ms/step - loss: 1.1058 - acc: 0.6542 - val_loss: 1.9222 - val_acc: 0.4609
# --------------- Epoch 31 Completed ---------------
#  nor may the speet be mone,
# shall shorl is but thou art, wherein not so singen:
#
# Epoch 33/200
# 70503/70503 [==============================] - 103s 1ms/step - loss: 1.0893 - acc: 0.6591 - val_loss: 1.9363 - val_acc: 0.4611
# --------------- Epoch 32 Completed ---------------
#  on, that moss wattire asb
# then of thy report that weatare be not faie,
#
# Epoch 34/200
# 70503/70503 [==============================] - 103s 1ms/step - loss: 1.0713 - acc: 0.6659 - val_loss: 1.9651 - val_acc: 0.4544
# --------------- Epoch 33 Completed ---------------
#  conot doth parch as field mure in sobles,
# or dive and avingle breathings have doth prows,
#
# Epoch 35/200
# 70503/70503 [==============================] - 103s 1ms/step - loss: 1.0557 - acc: 0.6705 - val_loss: 1.9800 - val_acc: 0.4548
# --------------- Epoch 34 Completed ---------------
# ratter sum.
# cay her bicked eyes having tother in thy day,
#
# Epoch 36/200
# 70503/70503 [==============================] - 103s 1ms/step - loss: 1.0401 - acc: 0.6758 - val_loss: 2.0031 - val_acc: 0.4533
# --------------- Epoch 35 Completed ---------------
# e heart's leave notel,
# be epence i since with this proudeply shight,
#
# Epoch 37/200
# 70503/70503 [==============================] - 103s 1ms/step - loss: 1.0252 - acc: 0.6792 - val_loss: 2.0304 - val_acc: 0.4518
# --------------- Epoch 36 Completed ---------------
#  when with tell of men.
#   the just my wealy their night contonce's wair thee
#
# Epoch 38/200
# 70503/70503 [==============================] - 102s 1ms/step - loss: 1.0097 - acc: 0.6831 - val_loss: 2.0446 - val_acc: 0.4544
# --------------- Epoch 37 Completed ---------------
# r not the embery
# and for thy plays of happy mo brouds increaser,
#
# Epoch 39/200
# 70503/70503 [==============================] - 102s 1ms/step - loss: 0.9948 - acc: 0.6884 - val_loss: 2.0678 - val_acc: 0.4515
# --------------- Epoch 38 Completed ---------------
# se the first aswast pride,
# yet thy self as inly spender mendule ye!
#
# Epoch 40/200
# 70503/70503 [==============================] - 103s 1ms/step - loss: 0.9857 - acc: 0.6915 - val_loss: 2.0886 - val_acc: 0.4506
# --------------- Epoch 39 Completed ---------------
# eauty shall hine
# the all with fair far lives in mine by deare,
#
# Epoch 41/200
# 70503/70503 [==============================] - 103s 1ms/step - loss: 0.9726 - acc: 0.6946 - val_loss: 2.1097 - val_acc: 0.4480
# --------------- Epoch 40 Completed ---------------
#  i would mose with wor,
# daik prosom expaintated in stranget
#
# Epoch 42/200
# 70503/70503 [==============================] - 104s 1ms/step - loss: 0.9583 - acc: 0.6989 - val_loss: 2.1305 - val_acc: 0.4423
# --------------- Epoch 41 Completed ---------------
# lifter lan when old have thy higry gen,
#   as fline of your sty age soulout time
#
# Epoch 43/200
# 70503/70503 [==============================] - 103s 1ms/step - loss: 0.9489 - acc: 0.7013 - val_loss: 2.1418 - val_acc: 0.4446
# --------------- Epoch 42 Completed ---------------
# s yur show where,
# the single all true' in offanlenclesobed,
#
# Epoch 44/200
# 70503/70503 [==============================] - 102s 1ms/step - loss: 0.9377 - acc: 0.7051 - val_loss: 2.1533 - val_acc: 0.4435
# --------------- Epoch 43 Completed ---------------
# ove's breath, in one gacked from
# thist men anothle the pyris, thou art on me,
#
# Epoch 45/200
# 70503/70503 [==============================] - 104s 1ms/step - loss: 0.9291 - acc: 0.7076 - val_loss: 2.1862 - val_acc: 0.4412
# --------------- Epoch 44 Completed ---------------
# beauty well other bad a know hath hem,
# for thy love is thine are mohethand thee,
#
# Epoch 46/200
# 70503/70503 [==============================] - 103s 1ms/step - loss: 0.9162 - acc: 0.7095 - val_loss: 2.2114 - val_acc: 0.4363
# --------------- Epoch 45 Completed ---------------
# t gite,
# that upon to couse call thy self the minh,
#
# Epoch 47/200
# 70503/70503 [==============================] - 102s 1ms/step - loss: 0.9082 - acc: 0.7136 - val_loss: 2.2148 - val_acc: 0.4382
# --------------- Epoch 46 Completed ---------------
# nd name, and to recotain) more:
# mare rake stauces their growt doth lity,
#
# Epoch 48/200
# 70503/70503 [==============================] - 102s 1ms/step - loss: 0.8979 - acc: 0.7175 - val_loss: 2.2482 - val_acc: 0.4382
# --------------- Epoch 47 Completed ---------------
# incest conker met.
# no commerit in think of this conomely.
#
# Epoch 49/200
# 70503/70503 [==============================] - 103s 1ms/step - loss: 0.8905 - acc: 0.7190 - val_loss: 2.2731 - val_acc: 0.4372
# --------------- Epoch 48 Completed ---------------
# d)
# and ruding that wricely knowledst kind,
#
# Epoch 50/200
# 70503/70503 [==============================] - 100s 1ms/step - loss: 0.8813 - acc: 0.7215 - val_loss: 2.2808 - val_acc: 0.4362
# --------------- Epoch 49 Completed ---------------
# end from the blow,
#   and my heary thou my best i wan where wint,
#
# Epoch 51/200
# 70503/70503 [==============================] - 101s 1ms/step - loss: 0.8709 - acc: 0.7249 - val_loss: 2.2813 - val_acc: 0.4368
# --------------- Epoch 50 Completed ---------------
# tpered see,
# these sagl extuble reppecty sincless with love's crown,
#
# Epoch 52/200
# 70503/70503 [==============================] - 103s 1ms/step - loss: 0.8642 - acc: 0.7263 - val_loss: 2.3280 - val_acc: 0.4344
# --------------- Epoch 51 Completed ---------------
# vange do shate.
#   for thou art should atimes with swiet besiled?
#
# Epoch 53/200
# 70503/70503 [==============================] - 104s 1ms/step - loss: 0.8588 - acc: 0.7269 - val_loss: 2.3274 - val_acc: 0.4325
# --------------- Epoch 52 Completed ---------------
#  and goants thy remumber show,
#   lowe so prest of your own when thou sheether mory.
#
# Epoch 54/200
# 70503/70503 [==============================] - 105s 1ms/step - loss: 0.8523 - acc: 0.7301 - val_loss: 2.3518 - val_acc: 0.4325
# --------------- Epoch 53 Completed ---------------
# acion wered,
# nor making spatencay (my verper teep:
#
# Epoch 55/200
# 70503/70503 [==============================] - 97s 1ms/step - loss: 0.8411 - acc: 0.7318 - val_loss: 2.3709 - val_acc: 0.4370
# --------------- Epoch 54 Completed ---------------
# lone.
#   they i at fair, the your this thou grow'st brignt,
#
# Epoch 56/200
# 70503/70503 [==============================] - 99s 1ms/step - loss: 0.8387 - acc: 0.7336 - val_loss: 2.3798 - val_acc: 0.4291
# --------------- Epoch 55 Completed ---------------
#  it hath were beritevess
#   the very percers (yeight underming,
#
# Epoch 57/200
# 70503/70503 [==============================] - 100s 1ms/step - loss: 0.8317 - acc: 0.7344 - val_loss: 2.3974 - val_acc: 0.4309
# --------------- Epoch 56 Completed ---------------
# y!
#   for thy edes on me hath my use from sheence:
#
# Epoch 58/200
# 70503/70503 [==============================] - 94s 1ms/step - loss: 0.8241 - acc: 0.7378 - val_loss: 2.3904 - val_acc: 0.4352
# --------------- Epoch 57 Completed ---------------
# ruches weich his viepery, whinks invoce:
# so than their worth to meast love to deal.
#
# Epoch 59/200
# 70503/70503 [==============================] - 98s 1ms/step - loss: 0.8181 - acc: 0.7401 - val_loss: 2.4085 - val_acc: 0.4326
# --------------- Epoch 58 Completed ---------------
# lf to thee oo shown
# out treeding it the day, dut so byse with all his:
#
# Epoch 60/200
# 70503/70503 [==============================] - 98s 1ms/step - loss: 0.8173 - acc: 0.7394 - val_loss: 2.4375 - val_acc: 0.4262
# --------------- Epoch 59 Completed ---------------
# ter as is writ, in hath doth larfilled:
# then behe'ruches th' well othle but in thee!
#
# Epoch 61/200
# 70503/70503 [==============================] - 101s 1ms/step - loss: 0.8113 - acc: 0.7421 - val_loss: 2.4420 - val_acc: 0.4290
# --------------- Epoch 60 Completed ---------------
# ow a fay thou should youth i would to heart:
#   and you i thy feash sutcered fair beauty;
#
# Epoch 62/200
# 70503/70503 [==============================] - 98s 1ms/step - loss: 0.8082 - acc: 0.7430 - val_loss: 2.4579 - val_acc: 0.4256
# --------------- Epoch 61 Completed ---------------
#
# rads this not if unuellion maje you know:

# %% [markdown]
# Generate example text from trained model.

# %%
# Load model
model = keras.models.load_model('RNN_char-LSTM.h5')

# Choose seed
seed = X_code[np.random.choice(len(X_code))]
print('Seed Sequence:')
print(''.join([code2char[code] for code in seed]))
print('')

# Generate sequences for different temperatures
for T in [0.5, 1, 1.5]:
    seq_out = gen_lines(model, seed, code2char, n_lines=14, T=T,
                        verbose=False)
    print('Output Sequence for Temperature %.1f:' % T)
    print(seq_out)
    print('')
# Out:
# Seed Sequence:
# sed in giving gentle doom:
# and taught it
#
# Output Sequence for Temperature 0.5:
#  see gove i prove your dessed,
# with thou art so doth atate, and in the stare,
#   then thou best but the state i hard showers thing and on still doth still,
# the beauty that to the dear doth sweet speak,
# when i for wist mich at the sparing thise in me.
#   ending of self more that thou with thee,
# and i all be the ofr and in praise,
# and and in the time the sprain beauty,
# and his the canss not the sore the have hor strong.
#   but thou some doth say my sall the come,
# and that i so should be the that for thee is doth friend.
#   but this with thou art for my self my live,
#   the come which not so sweet more of their infore,
#   the store of make my strongen and of me,
#
# Output Sequence for Temperature 1.0:
#  not in my look, dear,
# they nor heave grainejuct your live, and seech prase,
# agioss to mame with not that your shame
# by i desthing oo the faire, and the be:
#   gave and and chatist your fair a prepe.
#   i apen i lovers but the resing shalt)
# have bar of heart light a well of most me right?
# or sorfullefet long the lame being frost,
# the hame madiles of my-laed tatirle, when by die,
# of makiogn timst speirve brage shalt wecp
# achithers liver not slape no in my deare,
# all s your mabety of their con beauty's,
# saw it mare olo floaks of love wo weet,
# not leaving your befer's sweet suche,
#
# Output Sequence for Temperature 1.5:
#  all more, deew nots
# amboods maplixed fearongonifnerle's spedrdonys
# etent.
#   that froshmorr to trmale
# than frasel-ot, lood'ss, appperequibso) be,
# rid-i hrath hef put manwold, lrfess of wered,
#   tr-senkring thislowed por'itle, coeving atrel.
#  ssably fal, morklons and noch ill yutou, ly llefling,
#  vorerlaikry faur, finceems shadowuef clough,
# alove, be.
# but with betumn's frowir midin popniousk.
#  wardinne llake vouchay nermeal though a'e.
#  o' in thou time walede pubdfabkt they fint,
# to normarseds rude urpeautiy hocpennoceonr
